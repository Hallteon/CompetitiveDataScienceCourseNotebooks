# %%
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup
from tqdm import tqdm

# %%
page = requests.get('http://www.autonet.ru/auto/ttx')

# %%
soup = BeautifulSoup(page.text, 'lxml')

# %%
brands = soup.find('div', class_='brands-block')
brands_links = []

for brand in brands.find_all('li'):
    brands_links.append(brand.find('a').get('href'))

# %%
models_links = [] 

for brand_link in brands_links:
    brand_page = requests.get(f'http://www.autonet.ru{brand_link}')
    brand_soup = BeautifulSoup(brand_page.text, 'lxml')
    car_models = brand_soup.find('div', 'filter-models')
    
    for model in car_models.find_all('li'):
        models_links.append(f'http://www.autonet.ru{model.find("a").get("href")}')

# %%
models = pd.DataFrame(models_links, columns=['url']).sort_values(by=['url']).reset_index(drop=True)

# %%
models.to_csv('../data/car_models_urls.csv')

# %%
models['brand'] = models['url'].apply(lambda x: x.split('/')[-2])
models['model'] = models['url'].apply(lambda x: x.split('/')[-1])

# %%
models
# Out:
#                                                 url    brand        model
# 0        http://www.autonet.ru/auto/ttx/ac_cars/ace  ac_cars          ace
# 1      http://www.autonet.ru/auto/ttx/ac_cars/aceca  ac_cars        aceca
# 2      http://www.autonet.ru/auto/ttx/ac_cars/cobra  ac_cars        cobra
# 3      http://www.autonet.ru/auto/ttx/ac_cars/mamba  ac_cars        mamba
# 4           http://www.autonet.ru/auto/ttx/acura/cl    acura           cl
# ...                                             ...      ...          ...
# 1815      http://www.autonet.ru/auto/ttx/zotye/z300    zotye         z300
# 1816      http://www.autonet.ru/auto/ttx/zx/admiral       zx      admiral
# 1817    http://www.autonet.ru/auto/ttx/zx/changling       zx    changling
# 1818  http://www.autonet.ru/auto/ttx/zx/grand_tiger       zx  grand_tiger
# 1819     http://www.autonet.ru/auto/ttx/zx/landmark       zx     landmark
#
# [1820 rows x 3 columns]

# %%
df = pd.read_csv('https://stepik.org/media/attachments/lesson/866758/quickstart_train.csv')

# %%
url = []

special_models = ['bmw 320i', 'mercedes-benz e200', 'mini cooper', 'smart coupe', 'vw polo', 'vw polo vi', 'vw tiguan']

for model in df['model']:
    model_name = model.lower().split()

    if model in ['Tesla Model 3', 'Volkswagen ID.4 ', 'MINI CooperSE']:
        url.append(np.nan)
        continue
    
    elif model_name[0] == 'vw':
        url.append(f'http://www.autonet.ru/auto/ttx/volkswagen/{model_name[1]}')
    
    elif model_name[1] == 'e200':
        url.append(f'http://www.autonet.ru/auto/ttx/{model_name[0]}/e')
        
    elif model_name[1] == '320i':
        url.append(f'http://www.autonet.ru/auto/ttx/{model_name[0]}/3_series')
    
    elif model_name[1] == 'cooper':
        url.append(f'http://www.autonet.ru/auto/ttx/{model_name[0]}/hatch')
    
    elif model_name[1] == 'coupe':
        url.append(f'http://www.autonet.ru/auto/ttx/{model_name[0]}/fortwo')

    else:
        url.append(f'http://www.autonet.ru/auto/ttx/{model_name[0]}/{model_name[1]}')

# %%
df['url'] = url

# %%
urls_car_df = df[['car_id', 'model', 'url']]

# %%
urls_car_df
# Out:
#           car_id              model  \
# 0     y13744087j     Kia Rio X-line
# 1     O41613818T         VW Polo VI
# 2     d-2109686j    Renault Sandero
# 3     u29695600e  Mercedes-Benz GLC
# 4     N-8915870N    Renault Sandero
# ...          ...                ...
# 2332  j21246192N      Smart ForFour
# 2333  h-1554287F            Audi A4
# 2334  A15262612g            Kia Rio
# 2335  W-2514493U    Renault Sandero
# 2336  z-1337463D            VW Polo
#
#                                                    url
# 0               http://www.autonet.ru/auto/ttx/kia/rio
# 1       http://www.autonet.ru/auto/ttx/volkswagen/polo
# 2       http://www.autonet.ru/auto/ttx/renault/sandero
# 3     http://www.autonet.ru/auto/ttx/mercedes-benz/glc
# 4       http://www.autonet.ru/auto/ttx/renault/sandero
# ...                                                ...
# 2332      http://www.autonet.ru/auto/ttx/smart/forfour
# 2333            http://www.autonet.ru/auto/ttx/audi/a4
# 2334            http://www.autonet.ru/auto/ttx/kia/rio
# 2335    http://www.autonet.ru/auto/ttx/renault/sandero
# 2336    http://www.autonet.ru/auto/ttx/volkswagen/polo
#
# [2337 rows x 3 columns]

# %%
urls_car_df.to_csv('../data/cars_urls.csv')

# %%
models_data = {}

def get_car_info(car):
    if pd.notnull(car['url']):
        model_page = requests.get(car['url'])
        model_soup = BeautifulSoup(model_page.text, 'lxml')

        models_data[car['car_id']] = []
        mod_lists = model_soup.find_all('table', class_='mod-list-table')

        for mod_list in mod_lists:
            for mod in mod_list.find_all('tr')[1:]:
                name = mod.find('td', class_='mod').text.strip('\n')

                try:
                    carcass_inf = mod.find('td', class_='carcass').text.split()
                    carcass = carcass_inf[0]
                    doors = int(carcass_inf[1][1])
                    volume = int(mod.find('td', class_='volume').text.split()[0])
                    power = int(mod.find('td', class_='power').text.split()[0])
                    release_year = int(mod.find('td', class_='edition').text.split('-')[0].split('.')[-1])

                except:
                    continue

                else:
                    if carcass and doors and volume and power and release_year:
                        if release_year <= car['year_to_start']:
                            models_data[car['car_id']].append((name, release_year, carcass, doors, volume, power))

                        else:
                            continue

        if len(models_data[car['car_id']]) == 0:
            models_data[car['car_id']].append((np.nan, np.nan, np.nan, np.nan, np.nan, np.nan))
            
    else:
        models_data[car['car_id']] = []
        models_data[car['car_id']].append((np.nan, np.nan, np.nan, np.nan, np.nan, np.nan))

# %%
def pass_car_info(car):
    car_model = pd.DataFrame(car['car_id'], columns=['name', 'release_year', 'carcass', 'doors', 'volume', 'power']).sort_values(by=['name', 'release_year', 'carcass', 'doors', 'volume', 'power']).reset_index(drop=True)
    car_model = car_model.iloc[0]

# %%
df.apply(lambda x: get_car_info(x), axis=1)
# Out:
# 0       None
# 1       None
# 2       None
# 3       None
# 4       None
#         ...
# 2332    None
# 2333    None
# 2334    None
# 2335    None
# 2336    None
# Length: 2337, dtype: object

# %%
models_data
# Out:
# {'y13744087j': [('KIA Rio 1.4 MPI', 2015, 'седан', 4, 1396, 107),
#   ('KIA Rio 1.4 MPI', 2015, 'хэтчбек', 5, 1396, 107),
#   ('KIA Rio 1.6 MPI', 2015, 'седан', 4, 1591, 123),
#   ('KIA Rio 1.6 MPI', 2015, 'хэтчбек', 5, 1591, 123),
#   ('KIA Rio 1.4 MPI', 2014, 'седан', 4, 1396, 107),
#   ('KIA Rio 1.4 MPI', 2014, 'хэтчбек', 5, 1396, 107),
#   ('KIA Rio 1.4 MPI', 2011, 'седан', 4, 1396, 107),
#   ('KIA Rio 1.4 MPI', 2012, 'хэтчбек', 5, 1396, 107),
#   ('KIA Rio 1.6 MPI', 2014, 'седан', 4, 1591, 123),
#   ('KIA Rio 1.6 MPI', 2014, 'хэтчбек', 5, 1591, 123),
#   ('KIA Rio 1.6 MPI', 2011, 'седан', 4, 1591, 123),
#   ('KIA Rio 1.6 MPI', 2012, 'хэтчбек', 5, 1591, 123),
#   ('KIA Rio 1.1 CDRi', 2012, 'хэтчбек', 3, 1120, 75),
#   ('KIA Rio 1.1 CRDi', 2011, 'хэтчбек', 5, 1120, 75),
#   ('KIA Rio 1.2 MPI', 2011, 'хэтчбек', 5, 1248, 87),
#   ('KIA Rio 1.2 MPI', 2012, 'хэтчбек', 3, 1248, 87),
#   ('KIA Rio 1.2 MPI', 2012, 'седан', 4, 1248, 87),
#   ('KIA Rio 1.4 CDRi', 2012, 'хэтчбек', 3, 1396, 90),
#   ('KIA Rio 1.4 CRDi', 2011, 'хэтчбек', 5, 1396, 90),
#   ('KIA Rio 1.4 MPI', 2011, 'хэтчбек', 5, 1396, 107),
#   ('KIA Rio 1.4 MPI', 2012, 'хэтчбек', 3, 1396, 107),
#   ('KIA Rio 1.4 MPI', 2012, 'седан', 4, 1396, 107),
#   ('KIA Rio 1.4', 2009, 'хэтчбек', 5, 1399, 97),
#   ('KIA Rio 1.4', 2009, 'седан', 4, 1399, 97),
#   ('KIA Rio 1.4', 2009, 'хэтчбек', 5, 1399, 75),
#   ('KIA Rio 1.5 CRDi', 2009, 'хэтчбек', 5, 1493, 110),
#   ('KIA Rio 1.6', 2009, 'хэтчбек', 5, 1599, 112),
#   ('KIA Rio 1.6', 2009, 'седан', 4, 1599, 110),
#   ('KIA Rio 1.4', 2005, 'седан', 4, 1399, 97),
#   ('KIA Rio 1.4', 2005, 'хэтчбек', 5, 1399, 97),
#   ('KIA Rio 1.5 CRDi', 2005, 'седан', 4, 1493, 110),
#   ('KIA Rio 1.5 CRDi', 2005, 'хэтчбек', 5, 1493, 110),
#   ('KIA Rio 1.6', 2005, 'седан', 4, 1599, 112),
#   ('KIA Rio 1.6', 2005, 'хэтчбек', 5, 1599, 112),
#   ('KIA Rio 1.3', 2002, 'универсал', 5, 1343, 82),
#   ('KIA Rio 1.3', 2002, 'седан', 4, 1343, 82),
#   ('KIA Rio 1.5', 2002, 'универсал', 5, 1493, 97),
#   ('KIA Rio 1.5', 2002, 'седан', 4, 1493, 97),
#   ('KIA Rio 1.3', 2000, 'седан', 4, 1343, 75),
#   ('KIA Rio 1.3', 2000, 'универсал', 5, 1343, 75),
#   ('KIA Rio 1.5', 2000, 'седан', 4, 1493, 98),
#   ('KIA Rio 1.5', 2000, 'универсал', 5, 1493, 98)],
#  'O41613818T': [('Volkswagen Polo 1.6 105 л.с.', 2015, 'седан', 4, 1598, 105),
#   ('Volkswagen Polo 1.6 110 л.с.', 2015, 'седан', 4, 1598, 110),
#   ('Volkswagen Polo 1.6 85 л.с.', 2015, 'седан', 4, 1598, 85),
#   ('Volkswagen Polo 1.6 90 л.с.', 2015, 'седан', 4, 1598, 90),
#   ('Volkswagen Polo 1.2', 2014, 'хэтчбек', 5, 1198, 60),
#   ('Volkswagen Polo 1.2', 2014, 'хэтчбек', 5, 1198, 70),
#   ('Volkswagen Polo Sedan', 2014, 'седан', 4, 1598, 85),
#   ('Volkswagen Polo Sedan', 2010, 'седан', 4, 1598, 105),
#   ('Volkswagen Cross Polo 1.2', 2010, 'хэтчбек', 5, 1198, 70),
#   ('Volkswagen Cross Polo 1.2 TSI', 2010, 'хэтчбек', 5, 1197, 105),
#   ('Volkswagen Cross Polo 1.4', 2010, 'хэтчбек', 5, 1390, 85),
#   ('Volkswagen Cross Polo 1.6 TDI', 2010, 'хэтчбек', 5, 1598, 75),
#   ('Volkswagen Cross Polo 1.6 TDI', 2010, 'хэтчбек', 5, 1598, 90),
#   ('Volkswagen Cross Polo 1.6 TDI', 2010, 'хэтчбек', 5, 1598, 105),
#   ('Volkswagen Polo 1.2', 2009, 'хэтчбек', 5, 1198, 60),
#   ('Volkswagen Polo 1.2', 2009, 'хэтчбек', 5, 1198, 70),
#   ('Volkswagen Polo 1.2', 2009, 'хэтчбек', 3, 1198, 60),
#   ('Volkswagen Polo 1.2', 2009, 'хэтчбек', 3, 1198, 70),
#   ('Volkswagen Polo 1.2 TDI', 2009, 'хэтчбек', 5, 1199, 75),
#   ('Volkswagen Polo 1.2 TDI', 2009, 'хэтчбек', 3, 1199, 75),
#   ('Volkswagen Polo 1.2 TSI', 2009, 'хэтчбек', 5, 1197, 105),
#   ('Volkswagen Polo 1.2 TSI', 2009, 'хэтчбек', 3, 1197, 105),
#   ('Volkswagen Polo 1.2 TSI', 2009, 'хэтчбек', 5, 1197, 90),
#   ('Volkswagen Polo 1.2 TSI', 2009, 'хэтчбек', 3, 1197, 90),
#   ('Volkswagen Polo 1.4', 2009, 'хэтчбек', 5, 1390, 85),
#   ('Volkswagen Polo 1.4', 2009, 'хэтчбек', 3, 1390, 85),
#   ('Volkswagen Polo 1.6', 2010, 'седан', 4, 1598, 105),
#   ('Volkswagen Polo 1.6 BiFuel', 2010, 'хэтчбек', 5, 1598, 82),
#   ('Volkswagen Polo 1.6 BiFuel', 2010, 'хэтчбек', 3, 1598, 82),
#   ('Volkswagen Polo 1.6 TDI', 2009, 'хэтчбек', 5, 1598, 90),
#   ('Volkswagen Polo 1.6 TDI', 2009, 'хэтчбек', 5, 1598, 105),
#   ('Volkswagen Polo 1.6 TDI', 2009, 'хэтчбек', 3, 1598, 90),
#   ('Volkswagen Polo 1.6 TDI', 2009, 'хэтчбек', 3, 1598, 105),
#   ('Volkswagen Polo GTI 1.4 TSI', 2009, 'хэтчбек', 3, 1390, 180),
#   ('Volkswagen Cross Polo 1.2', 2007, 'хэтчбек', 5, 1198, 70),
#   ('Volkswagen Cross Polo 1.2', 2005, 'хэтчбек', 5, 1198, 64),
#   ('Volkswagen Cross Polo 1.4', 2006, 'хэтчбек', 5, 1390, 80),
#   ('Volkswagen Cross Polo 1.4', 2005, 'хэтчбек', 5, 1390, 75),
#   ('Volkswagen Cross Polo 1.4', 2005, 'хэтчбек', 5, 1390, 100),
#   ('Volkswagen Cross Polo 1.4 TD', 2005, 'хэтчбек', 5, 1422, 70),
#   ('Volkswagen Cross Polo 1.6', 2006, 'хэтчбек', 5, 1598, 105),
#   ('Volkswagen Cross Polo 1.9 TD', 2005, 'хэтчбек', 5, 1896, 100),
#   ('Volkswagen Polo 1.2', 2007, 'хэтчбек', 3, 1198, 60),
#   ('Volkswagen Polo 1.2', 2007, 'хэтчбек', 5, 1198, 60),
#   ('Volkswagen Polo 1.2', 2007, 'хэтчбек', 3, 1198, 70),
#   ('Volkswagen Polo 1.2', 2007, 'хэтчбек', 5, 1198, 70),
#   ('Volkswagen Polo 1.2', 2005, 'хэтчбек', 3, 1198, 55),
#   ('Volkswagen Polo 1.2', 2005, 'хэтчбек', 3, 1198, 64),
#   ('Volkswagen Polo 1.2', 2005, 'хэтчбек', 5, 1198, 55),
#   ('Volkswagen Polo 1.2', 2005, 'хэтчбек', 5, 1198, 64),
#   ('Volkswagen Polo 1.4', 2006, 'хэтчбек', 3, 1390, 80),
#   ('Volkswagen Polo 1.4', 2006, 'хэтчбек', 5, 1390, 80),
#   ('Volkswagen Polo 1.4', 2005, 'хэтчбек', 3, 1390, 100),
#   ('Volkswagen Polo 1.4', 2005, 'хэтчбек', 5, 1390, 100),
#   ('Volkswagen Polo 1.4 FSI', 2005, 'хэтчбек', 3, 1390, 86),
#   ('Volkswagen Polo 1.4 FSI', 2005, 'хэтчбек', 5, 1390, 86),
#   ('Volkswagen Polo 1.4 TD', 2005, 'хэтчбек', 3, 1422, 70),
#   ('Volkswagen Polo 1.4 TD', 2005, 'хэтчбек', 3, 1422, 80),
#   ('Volkswagen Polo 1.4 TD', 2005, 'хэтчбек', 5, 1422, 70),
#   ('Volkswagen Polo 1.4 TD', 2005, 'хэтчбек', 5, 1422, 80),
#   ('Volkswagen Polo 1.6', 2006, 'хэтчбек', 3, 1598, 105),
#   ('Volkswagen Polo 1.6', 2006, 'хэтчбек', 5, 1598, 105),
#   ('Volkswagen Polo 1.8 GTI', 2006, 'хэтчбек', 3, 1781, 150),
#   ('Volkswagen Polo 1.8 T GTI Cup Edition', 2006, 'хэтчбек', 3, 1781, 180),
#   ('Volkswagen Polo 1.9 TD', 2005, 'хэтчбек', 3, 1986, 100),
#   ('Volkswagen Polo 1.9 TD', 2005, 'хэтчбек', 3, 1986, 130),
#   ('Volkswagen Polo 1.9 TD', 2005, 'хэтчбек', 5, 1986, 100),
#   ('Volkswagen Polo 1.9 TD', 2005, 'хэтчбек', 5, 1986, 130),
#   ('Volkswagen Polo 1.2', 2001, 'хэтчбек', 3, 1198, 54),
#   ('Volkswagen Polo 1.2', 2001, 'хэтчбек', 5, 1198, 54),
#   ('Volkswagen Polo 1.2', 2001, 'хэтчбек', 3, 1198, 64),
#   ('Volkswagen Polo 1.2', 2001, 'хэтчбек', 5, 1198, 64),
#   ('Volkswagen Polo 1.4 16V', 2001, 'хэтчбек', 3, 1390, 75),
#   ('Volkswagen Polo 1.4 16V', 2001, 'хэтчбек', 5, 1390, 75),
#   ('Volkswagen Polo 1.4 16V', 2002, 'хэтчбек', 3, 1390, 101),
#   ('Volkswagen Polo 1.4 16V', 2002, 'хэтчбек', 5, 1390, 101),
#   ('Volkswagen Polo 1.4 16V', 2003, 'седан', 4, 1390, 101),
#   ('Volkswagen Polo 1.4 16V', 2003, 'седан', 4, 1390, 75),
#   ('Volkswagen Polo 1.4 FSI', 2002, 'хэтчбек', 3, 1390, 86),
#   ('Volkswagen Polo 1.4 FSI', 2002, 'хэтчбек', 5, 1390, 86),
#   ('Volkswagen Polo 1.4 TD', 2001, 'хэтчбек', 3, 1422, 75),
#   ('Volkswagen Polo 1.4 TD', 2001, 'хэтчбек', 5, 1422, 75),
#   ('Volkswagen Polo 1.4 TD', 2001, 'хэтчбек', 5, 1422, 75),
#   ('Volkswagen Polo 1.4 TD', 2003, 'седан', 4, 1422, 75),
#   ('Volkswagen Polo 1.9 TD', 2001, 'хэтчбек', 3, 1896, 64),
#   ('Volkswagen Polo 1.9 TD', 2001, 'хэтчбек', 3, 1896, 101),
#   ('Volkswagen Polo 1.9 TD', 2001, 'хэтчбек', 5, 1896, 101),
#   ('Volkswagen Polo 1.9 TD', 2001, 'хэтчбек', 5, 1896, 64),
#   ('Volkswagen Polo 1.9 TD', 2003, 'хэтчбек', 3, 1896, 130),
#   ('Volkswagen Polo 1.9 TD', 2003, 'хэтчбек', 5, 1896, 130),
#   ('Volkswagen Polo 1.9 TD', 2003, 'седан', 4, 1896, 64),
#   ('Volkswagen Polo Fun 1.2', 2003, 'хэтчбек', 5, 1198, 54),
#   ('Volkswagen Polo Fun 1.2', 2003, 'хэтчбек', 5, 1198, 64),
#   ('Volkswagen Polo Fun 1.4 16V', 2003, 'хэтчбек', 5, 1390, 101),
#   ('Volkswagen Polo Fun 1.4 FSI', 2003, 'хэтчбек', 5, 1390, 86),
#   ('Volkswagen Polo Fun 1.4 TD', 2003, 'хэтчбек', 5, 1422, 75),
#   ('Volkswagen Polo Fun 1.9 TD', 2003, 'хэтчбек', 5, 1896, 101),
#   ('Volkswagen Polo Classic 1.4', 1999, 'седан', 4, 1390, 75),
#   ('Volkswagen Polo Classic 1.4', 1999, 'седан', 4, 1390, 60),
#   ('Volkswagen Polo Classic 1.6', 1999, 'седан', 4, 1595, 101),
#   ('Volkswagen Polo Classic 1.9 D', 1999, 'седан', 4, 1896, 68),
#   ('Volkswagen Polo Classic 1.9 TD', 1999, 'седан', 4, 1896, 90),
#   ('Volkswagen Polo Classic 1.9 TD', 1999, 'седан', 4, 1896, 110),
#   ('Volkswagen Polo Variant 1.4', 1999, 'универсал', 5, 1390, 75),
#   ('Volkswagen Polo Variant 1.4', 1999, 'универсал', 5, 1390, 60),
#   ('Volkswagen Polo Variant 1.6', 1999, 'универсал', 5, 1595, 101),
#   ('Volkswagen Polo Variant 1.9 D', 1999, 'универсал', 5, 1896, 68),
#   ('Volkswagen Polo Variant 1.9 TD', 1999, 'универсал', 5, 1896, 90),
#   ('Volkswagen Polo Variant 1.9 TD', 1999, 'универсал', 5, 1896, 110),
#   ('Volkswagen Polo 1.0', 1999, 'хэтчбек', 3, 999, 50),
#   ('Volkswagen Polo 1.0', 1999, 'хэтчбек', 5, 999, 50),
#   ('Volkswagen Polo 1.4', 1999, 'хэтчбек', 3, 1390, 75),
#   ('Volkswagen Polo 1.4', 1999, 'хэтчбек', 5, 1390, 75),
#   ('Volkswagen Polo 1.4', 1999, 'хэтчбек', 3, 1390, 60),
#   ('Volkswagen Polo 1.4', 1999, 'хэтчбек', 5, 1390, 60),
#   ('Volkswagen Polo 1.4 16V', 1999, 'хэтчбек', 3, 1390, 101),
#   ('Volkswagen Polo 1.4 16V', 1999, 'хэтчбек', 5, 1390, 101),
#   ('Volkswagen Polo 1.4 TD', 1999, 'хэтчбек', 3, 1422, 75),
#   ('Volkswagen Polo 1.4 TD', 1999, 'хэтчбек', 5, 1422, 75),
#   ('Volkswagen Polo 1.6 16V', 1999, 'хэтчбек', 3, 1598, 125),
#   ('Volkswagen Polo 1.6 16V', 1999, 'хэтчбек', 5, 1598, 125),
#   ('Volkswagen Polo 1.7 D', 1999, 'хэтчбек', 3, 1716, 60),
#   ('Volkswagen Polo 1.7 D', 1999, 'хэтчбек', 5, 1716, 60),
#   ('Volkswagen Polo 1.9 D', 1999, 'хэтчбек', 3, 1896, 64),
#   ('Volkswagen Polo 1.9 D', 1999, 'хэтчбек', 5, 1896, 64),
#   ('Volkswagen Polo Variant 1.4', 1997, 'универсал', 5, 1390, 60),
#   ('Volkswagen Polo Variant 1.6', 1997, 'универсал', 5, 1595, 101),
#   ('Volkswagen Polo Variant 1.6', 1997, 'универсал', 5, 1598, 75),
#   ('Volkswagen Polo Variant 1.7 SDI', 1997, 'универсал', 5, 1716, 60),
#   ('Volkswagen Polo Variant 1.9 TD', 1997, 'универсал', 5, 1896, 90),
#   ('Volkswagen Polo Variant 1.9 TD', 1998, 'универсал', 5, 1896, 110),
#   ('Volkswagen Polo Classic 1.4', 1995, 'седан', 4, 1390, 60),
#   ('Volkswagen Polo Classic 1.6', 1996, 'седан', 4, 1595, 100),
#   ('Volkswagen Polo Classic 1.6', 1996, 'седан', 4, 1598, 75),
#   ('Volkswagen Polo Classic 1.7 SDI', 1997, 'седан', 4, 1716, 60),
#   ('Volkswagen Polo Classic 1.9 SDI', 1996, 'седан', 4, 1896, 64),
#   ('Volkswagen Polo Classic 1.9 TD', 1997, 'седан', 4, 1896, 90),
#   ('Volkswagen Polo Classic 1.9 TD', 1998, 'седан', 4, 1896, 110),
#   ('Volkswagen Polo 1.0', 1996, 'хэтчбек', 3, 999, 50),
#   ('Volkswagen Polo 1.0', 1996, 'хэтчбек', 5, 999, 50),
#   ('Volkswagen Polo 1.0', 1994, 'хэтчбек', 3, 1043, 45),
#   ('Volkswagen Polo 1.0', 1994, 'хэтчбек', 5, 1043, 45),
#   ('Volkswagen Polo 1.4', 1995, 'хэтчбек', 3, 1390, 60),
#   ('Volkswagen Polo 1.4', 1995, 'хэтчбек', 5, 1390, 60),
#   ('Volkswagen Polo 1.4', 1994, 'хэтчбек', 3, 1296, 55),
#   ('Volkswagen Polo 1.4', 1994, 'хэтчбек', 5, 1296, 55),
#   ('Volkswagen Polo 1.4 16V', 1996, 'хэтчбек', 3, 1390, 100),
#   ('Volkswagen Polo 1.4 16V', 1996, 'хэтчбек', 5, 1390, 100),
#   ('Volkswagen Polo 1.6', 1994, 'хэтчбек', 3, 1598, 75),
#   ('Volkswagen Polo 1.6', 1994, 'хэтчбек', 5, 1598, 75),
#   ('Volkswagen Polo 1.7 SDI', 1999, 'хэтчбек', 3, 1716, 60),
#   ('Volkswagen Polo 1.7 SDI', 1999, 'хэтчбек', 5, 1716, 60),
#   ('Volkswagen Polo 1.9 SDI', 1994, 'хэтчбек', 3, 1896, 64),
#   ('Volkswagen Polo 1.9 SDI', 1994, 'хэтчбек', 5, 1896, 64),
#   ('Volkswagen Polo 1.0', 1990, 'хэтчбек', 3, 1043, 45),
#   ('Volkswagen Polo 1.0', 1990, 'купе', 3, 1043, 45),
#   ('Volkswagen Polo 1.0', 1990, 'седан', 2, 1043, 45),
#   ('Volkswagen Polo 1.4 D', 1990, 'хэтчбек', 3, 1398, 48),
#   ('Volkswagen Polo 1.4 D', 1990, 'купе', 3, 1398, 48),
#   ('Volkswagen Polo 1.4 D', 1990, 'седан', 2, 1398, 48),
#   ('Volkswagen Polo 1.0', 1985, 'купе', 3, 1043, 45),
#   ('Volkswagen Polo 1.0', 1985, 'хэтчбек', 3, 1043, 45),
#   ('Volkswagen Polo 1.0', 1985, 'седан', 2, 1043, 45),
#   ('Volkswagen Polo 1.3', 1985, 'купе', 3, 1272, 75),
#   ('Volkswagen Polo 1.3', 1985, 'хэтчбек', 3, 1272, 75),
#   ('Volkswagen Polo 1.3', 1985, 'купе', 3, 1272, 54),
#   ('Volkswagen Polo 1.3', 1985, 'хэтчбек', 3, 1272, 54),
#   ('Volkswagen Polo 1.3', 1985, 'седан', 2, 1272, 54),
#   ('Volkswagen Polo 1.3', 1982, 'хэтчбек', 3, 1272, 75),
#   ('Volkswagen Polo 1.3', 1983, 'хэтчбек', 3, 1272, 54),
#   ('Volkswagen Polo 1.3', 1982, 'седан', 2, 1272, 54),
#   ('Volkswagen Polo 1.3', 1983, 'купе', 3, 1272, 54),
#   ('Volkswagen Polo 1.3', 1982, 'купе', 3, 1272, 75)],
#  'd-2109686j': [('Renault Sandero 1.4', 2009, 'хэтчбек', 5, 1390, 75),
#   ('Renault Sandero 1.6', 2009, 'хэтчбек', 5, 1598, 84),
#   ('Renault Sandero 1.6', 2009, 'хэтчбек', 5, 1598, 102),
#   ('Renault Sandero Stepway 1.6', 2008, 'внедорожник', 5, 1598, 112),
#   ('Renault Sandero Stepway 1.6', 2008, 'внедорожник', 5, 1598, 107),
#   ('Renault Sandero Stepway(RU) 1.6', 2010, 'внедорожник', 5, 1598, 84),
#   ('Renault Sandero Stepway(RU) 1.6', 2010, 'внедорожник', 5, 1598, 103)],
#  'u29695600e': [(nan, nan, nan, nan, nan, nan)],
#  'N-8915870N': [('Renault Sandero 1.4', 2009, 'хэтчбек', 5, 1390, 75),
#   ('Renault Sandero 1.6', 2009, 'хэтчбек', 5, 1598, 84),
#   ('Renault Sandero 1.6', 2009, 'хэтчбек', 5, 1598, 102),
#   ('Renault Sandero Stepway 1.6', 2008, 'внедорожник', 5, 1598, 112),
#   ('Renault Sandero Stepway 1.6', 2008, 'внедорожник', 5, 1598, 107),
#   ('Renault Sandero Stepway(RU) 1.6', 2010, 'внедорожник', 5, 1598, 84),
#   ('Renault Sandero Stepway(RU) 1.6', 2010, 'внедорожник', 5, 1598, 103)]}

# %%
df.loc[df['model'] == 'Tesla Model 3']
# Out:
#           car_id          model car_type fuel_type  car_rating  year_to_start  \
# 7     O-2124190y  Tesla Model 3  premium   electro        3.90           2017
# 99    n19871201N  Tesla Model 3  premium   electro        3.58           2016
# 187   I13914989Z  Tesla Model 3  premium   electro        4.64           2016
# 218   g-2283000q  Tesla Model 3  premium   electro        5.44           2015
# 505   i-1106718P  Tesla Model 3  premium   electro        4.72           2015
# 685   I-2073229s  Tesla Model 3  premium   electro        5.10           2017
# 1120  N44849090k  Tesla Model 3  premium   electro        3.60           2015
# 1192  T20813001U  Tesla Model 3  premium   electro        3.98           2017
# 1245  O-2688441F  Tesla Model 3  premium   electro        4.82           2015
# 1447  p22133368b  Tesla Model 3  premium   electro        3.06           2014
# 1661  T19756755G  Tesla Model 3  premium   electro        3.12           2017
# 1702  v22568580b  Tesla Model 3  premium   electro        5.66           2015
# 1809  l-1177682G  Tesla Model 3  premium   electro        4.46           2016
# 1867  h-1921200Q  Tesla Model 3  premium   electro        4.78           2015
#
#       riders  year_to_work  target_reg     target_class  mean_rating  \
# 7     116872          2019       50.40       gear_stick     4.712356
# 99     89811          2018       99.17      another_bug     4.648448
# 187    98304          2019      103.75  engine_ignition     4.152241
# 218    75113          2020       49.28       gear_stick     4.413736
# 505    75786          2017      120.33  engine_ignition     3.839828
# 685   120231          2017       58.11      engine_fuel     4.083851
# 1120   86115          2022       58.50      electro_bug     4.186149
# 1192  132784          2017       54.48      engine_fuel     3.951782
# 1245   80038          2021       58.85      engine_fuel     4.556149
# 1447   66621          2019       64.58      electro_bug     4.279713
# 1661  135804          2018      114.02      another_bug     4.487241
# 1702   87889          2021      103.57     engine_check     4.665287
# 1809  105697          2020       75.43     engine_check     4.505230
# 1867   93044          2019       61.19        break_bug     5.255345
#
#       distance_sum  rating_min   speed_max  user_ride_quality_median  \
# 7     9.793288e+06        0.10   95.890736                 -8.939366
# 99    1.023756e+07        0.10  195.243961                  6.716249
# 187   1.291300e+07        0.10  195.321301                  7.404675
# 218   1.436422e+07        0.10  101.976813                 -0.650539
# 505   1.631738e+07        0.10  197.938901                -12.254816
# 685   1.625174e+07        0.10  191.425146                 -6.045260
# 1120  1.578276e+07        0.00  199.370103                  3.385336
# 1192  1.256057e+07        0.10  174.458376                -10.913769
# 1245  1.027493e+07        0.10  169.368375                  4.348376
# 1447  9.146520e+06        0.00  180.831626                 -5.150000
# 1661  1.455982e+07        0.10  197.000000                  1.725496
# 1702  1.018316e+07        0.10  157.000000                  0.623220
# 1809  6.140716e+06        0.21  162.207987                 -7.747989
# 1867  1.556993e+07        0.10  105.886396                 -6.644752
#
#       deviation_normal_count  user_uniq  url
# 7                        174        139  NaN
# 99                       174        147  NaN
# 187                      174        150  NaN
# 218                      174        141  NaN
# 505                      174        146  NaN
# 685                      174        144  NaN
# 1120                     174        148  NaN
# 1192                     174        138  NaN
# 1245                     174        139  NaN
# 1447                     174        151  NaN
# 1661                     174        136  NaN
# 1702                     174        141  NaN
# 1809                     174        139  NaN
# 1867                     174        150  NaN
